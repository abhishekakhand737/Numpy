# %% [markdown]
# ## String Operation, Comparison and information in NUMPY

# %%
import numpy as np

# %%
ch_name = "Artificial Intelligence"
str1 = "Data Science"

# %%
np.char.add(ch_name  ,  str1)
# Out:
# np.str_('Artificial IntelligenceData Science')

# %%
np.char.lower(ch_name)
# Out:
# array('artificial intelligence', dtype='<U23')

# %%
np.char.upper(ch_name)
# Out:
# array('ARTIFICIAL INTELLIGENCE', dtype='<U23')

# %%
np.char.upper(str1)
# Out:
# array('DATA SCIENCE', dtype='<U12')

# %%
np.char.center(str1, 60)
# Out:
# array('                        Data Science                        ',
#       dtype='<U60')

# %%
np.char.center(str1, 60, fillchar="*")
# Out:
# array('************************Data Science************************',
#       dtype='<U60')

# %%
np.char.split(ch_name)
# Out:
# array(list(['Artificial', 'Intelligence']), dtype=object)

# %%
np.char.splitlines("hello\nBrother")
# Out:
# array(list(['hello', 'Brother']), dtype=object)

# %%
str3 = "dmy"
str4 = "dmy"

# %%
np.char.join([":", "/"],[str3,str4])
# Out:
# array(['d:m:y', 'd/m/y'], dtype='<U5')

# %%
np.char.replace(ch_name,"Artificial","AI")
# Out:
# array('AI Intelligence', dtype='<U15')

# %% [markdown]
# ## Comparison Method

# %%
str11 = "abhi"
str12 = "abhijeet"

# %%
np.char.equal(str1,str2)
# Out:
# array(False)

# %%
str11 = "abhi"
str12 = "abhi"
np.char.equal(str1,str2)
# Out:
# array(True)

# %%
int(             np.char.count(ch_name,"a"        )             )
# Out:
# 1

# %%
int(             np.char.count(ch_name,"i"        )             )
# Out:
# 4

# %%
ch_name
# Out:
# 'Artificial Intelligence'

# %%
int(         np.char.find(ch_name, "A")               )
# Out:
# 0

# %%
int(         np.char.find(ch_name, "I")               )
# Out:
# 11
